# %% [markdown]
# ## Day34.YOLO 細節理解 - 損失函數
# 今天的課程，我們講述了
# * 損失函數是描述模型預測出來的結果和實際的差異的依據
# * YOLO 損失函數的設計包含物件位置的定位與物件類別辨識
# * YOLO損失函數透過超參數設定模型有不同的辨識能力

# %% [markdown]
# ### 作業
# 仔細觀察，bbox 寬高計算損失方式和bbox中心計算損失方式有哪邊不一樣嗎? 為什麼要有不同的設計?
# ![title](loss function.png)

# %%
'''
bbox寬高是先把寬高開開根號後，再算差異的平方，
主要是因為預測框較大容易產生很大的誤差，
如果損失方式和中心點相同，會造成模型大物體辨識的差，因此透過開根號修正這樣的情形。

作業提供的圖，代表x和開根號x的關係，
大物體的預測誤差，和小物體的預測誤差都為同值時，透過開根號，
大物體的預測誤差量會小於小物體的預測誤差量，
達到大小物件辨識能力接近的設計。

'''
# Out:
# '\nbbox寬高是先把寬高開開根號後，再算差異的平方，\n主要是因為預測框較大容易產生很大的誤差，\n如果損失方式和中心點相同，會造成模型大物體辨識的差，因此透過開根號修正這樣的情形。\n\n作業提供的圖，代表x和開根號x的關係，\n大物體的預測誤差，和小物體的預測誤差都為同值時，透過開根號，\n大物體的預測誤差量會小於小物體的預測誤差量，\n達到大小物件辨識能力接近的設計。\n\n'

# %% [markdown]
# * <img src="Day034_HW_answer.png" align=left></img>
